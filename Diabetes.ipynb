# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('D:\work\data sets\Diabetes/diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data.keys()
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data.shape
# Out:
# (768, 9)

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.isna().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
from numpy import NAN

# %%
data['Glucose']=data['Glucose'].replace(0,NAN)

# %%
data['BloodPressure']=data['BloodPressure'].replace(0,NAN)

# %%
data['SkinThickness']=data['SkinThickness'].replace(0,NAN)

# %%
data['Insulin']=data['Insulin'].replace(0,NAN)

# %%
data['BMI']=data['BMI'].replace(0,NAN)

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  763.000000     733.000000     541.000000  394.000000
# mean      3.845052  121.686763      72.405184      29.153420  155.548223
# std       3.369578   30.535641      12.382158      10.476982  118.775855
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      64.000000      22.000000   76.250000
# 50%       3.000000  117.000000      72.000000      29.000000  125.000000
# 75%       6.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  768.000000  768.000000
# mean    32.457464                  0.471876   33.240885    0.348958
# std      6.924988                  0.331329   11.760232    0.476951
# ...

# %%
data.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
data.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                29.0000
# Insulin                     125.0000
# BMI                          32.3000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %%
data.fillna(data.median(),inplace=True)
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0    125.0  33.6
# 1              1     85.0           66.0           29.0    125.0  26.6
# 2              8    183.0           64.0           29.0    125.0  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0    125.0  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0           29.0    125.0  30.1
# 767            1     93.0           70.0           31.0    125.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # outliers Detection and treatment

# %%
plt.figure(figsize=(15,10))

plt.subplot(4,4,1)
sns.boxplot(data['Pregnancies'])

plt.subplot(4,4,2)
sns.boxplot(data['Glucose'])

plt.subplot(4,4,3)
sns.boxplot(data['BloodPressure'])

plt.subplot(4,4,4)
sns.boxplot(data['SkinThickness'])

plt.subplot(4,4,5)
sns.boxplot(data['Insulin'])

plt.subplot(4,4,6)
sns.boxplot(data['BMI'])

plt.subplot(4,4,7)
sns.boxplot(data['DiabetesPedigreeFunction'])


plt.subplot(4,4,8)
sns.boxplot(data['Age'])
# Out:
# C:\Users\karthik ns\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\karthik ns\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
* apart from glucose all other attributes have a outliers .these lower level and upper level outliers
are replaced with 5th(.05) and 95th(.95) percentile respectively

# %%
* numpy.clip()function is used to clip(limit)the values in an array.

SYNTAX=numpy.clip(a,a_min,a_max,out=None)
parameters,
   a :Array containing elements to clip
a_min:Minimum value
a_Max:Maximum value
if clipping is not performed on the lower interval edge.not more than one of a_min and a_max may be None

# %%
data['Pregnancies']=data['Pregnancies'].clip(lower=data['Pregnancies'].quantile(.05),upper=data['Pregnancies'].quantile(.95))

# %%
data['Glucose']=data['Glucose'].clip(lower=data['Glucose'].quantile(.05),upper=data['Glucose'].quantile(.95))

# %%
data['BloodPressure']=data['BloodPressure'].clip(lower=data['BloodPressure'].quantile(.05),upper=data['BloodPressure'].quantile(.95))

# %%
data['SkinThickness']=data['SkinThickness'].clip(lower=data['SkinThickness'].quantile(.05),upper=data['SkinThickness'].quantile(.95))

# %%
data['Insulin']=data['Insulin'].clip(lower=data['Insulin'].quantile(.05),upper=data['Insulin'].quantile(.95))

# %%
data['BMI']=data['BMI'].clip(lower=data['BMI'].quantile(.05),upper=data['BMI'].quantile(.95))

# %%
data['DiabetesPedigreeFunction']=data['DiabetesPedigreeFunction'].clip(lower=data['DiabetesPedigreeFunction'].quantile(.05),upper=data['DiabetesPedigreeFunction'].quantile(.95))

# %%
data['Age']=data['Age'].clip(lower=data['Age'].quantile(.05),upper=data['Age'].quantile(.95))

# %%
plt.figure(figsize=(15,10))

plt.subplot(4,4,1)
sns.boxplot(data['Pregnancies'])

plt.subplot(4,4,2)
sns.boxplot(data['Glucose'])

plt.subplot(4,4,3)
sns.boxplot(data['BloodPressure'])

plt.subplot(4,4,4)
sns.boxplot(data['SkinThickness'])

plt.subplot(4,4,5)
sns.boxplot(data['Insulin'])

plt.subplot(4,4,6)
sns.boxplot(data['BMI'])

plt.subplot(4,4,7)
sns.boxplot(data['DiabetesPedigreeFunction'])


plt.subplot(4,4,8)
sns.boxplot(data['Age'])
# Out:
# C:\Users\karthik ns\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\karthik ns\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
* as we can still see the outliers in skinthickness and insulin .lets try manipulating the percentile values.

# %%
data['SkinThickness']=data['SkinThickness'].clip(lower=data['SkinThickness'].quantile(.07),upper=data['SkinThickness'].quantile(.93))

# %%
data['Insulin']=data['Insulin'].clip(lower=data['Insulin'].quantile(.21),upper=data['Insulin'].quantile(.80))

# %%
plt.figure(figsize=(20,15))

plt.subplot(4,4,4)
sns.boxplot(data['SkinThickness'])

plt.subplot(4,4,5)
sns.boxplot(data['Insulin'])
# Out:
# C:\Users\karthik ns\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\karthik ns\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Insulin'>

# %%
* still we have  a oulier for insulin so lets try some more manipulating percentile value

# %%
data['Insulin']=data['Insulin'].clip(lower=data['Insulin'].quantile(.25),upper=data['Insulin'].quantile(.75))

# %%
plt.figure(figsize=(20,15))

plt.subplot(4,4,5)
sns.boxplot(data['Insulin'])
# Out:
# C:\Users\karthik ns\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Insulin'>

# %%
* as we can see there is no outlier for the insulin,,, we are good to go further

# %% [markdown]
# # Data Visualization

# %%
sns.countplot(data['Outcome'])
# Out:
# C:\Users\karthik ns\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
* lets plot a corelation plot .this polt will help us to understand themulti colinearity in the data set

# %%
f,ax=plt.subplots(figsize=(20,10))
corr = data.corr('pearson')
sns.heatmap(corr,mask=np.zeros_like(corr,dtype=np.bool),cmap=sns.diverging_palette(220,10,as_cmap=True),
           square=True,ax=ax,annot=True)
# Out:
# <ipython-input-60-0a9d0ff7be71>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(corr,mask=np.zeros_like(corr,dtype=np.bool),cmap=sns.diverging_palette(220,10,as_cmap=True),
# <AxesSubplot:>

# %%
sns.pairplot(data,hue='Outcome',diag_kind='kde')
